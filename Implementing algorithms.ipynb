# %%
# Test

import pymoo as P
from pymoo.util.plotting import plot
import RTEA

# %%
problem = P.problems.get_problem('zdt1')
print(problem)
plot(problem.pareto_front(), no_fill=True)
# Out:
# # name: ZDT1
# # n_var: 30
# # n_obj: 2
# # n_ieq_constr: 0
# # n_eq_constr: 0
